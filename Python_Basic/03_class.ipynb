# %% [markdown]
# # Definicion y operaciones con variables de naturaleza numerica

# %%
# Definicion de variables (en python es muy natural y simple)

# El nombre que le vamos a dar a una variables debe tener relacion coherente con el uso
# o el entorno en el que la vamos a utilizar

peso = 116 # unidad : kilo
estatura = 1.75 # unidad : metro

# %%
# En vez de utilizar un nombre tan extenso (y explicito / autodescriptivo) para una
# variable determinada, es mejor utilizar un comentario
valor_de_la_gravedad_a_los_1800msnm = 9.785

# %%
# En cualquier momento podemos utilizar la funcion type
# Nos comunica que tipo de dato es un objeto/variable en particular
type(peso)
# Out:
# int

# %%
# De igual manera :
type(estatura)
# Out:
# float

# %%
# Python es un lenguaje de programacion de tipado dinamico

# %%
# Definamos una variables para almacenar la edad de mi cliente
edad = 44

# %%
type(edad)
# Out:
# int

# %%
#
edad = "cuarenta y cuatro"

# %%
type(edad)
# Out:
# str

# %% [markdown]
# ## Operaciones con variables de naturaleza numerica
#
# - `+` : operacion suma
# - `-` : operacion resta
# - `*` : multiplicacion
# - `/` : division
# - `**` : potenciacion
#
# **Observacion** : No hay que olvidar el uso de parentesis para operaciones complejas.
#
# Algoritmo de Euclides : `D = d * q + r`
#
#     * Cociente : `q = D // d`
#
#     * Residuo : `r = D % d`

# %%
# Ejemplito : Un rectangulo tiene un perimetro de 34cm y un area de 60cm2. Halla sus dimensiones
# y luego construye un cuadrado con el mismo perimetro y calcula su area.
# Tambien puedes calcular la diferencia de areas.

# %%
# Para el rectangulo :
lado = 8.5

# Calculo del area
area = lado**2
area
# Out:
# 72.25

# %%
# Diferencia de areas
area - 60
# Out:
# 12.25

# %% [markdown]
# ## El modulo matematico

# %%
# Importar el modulo math
import math as m

# %%
# Accedamos a la documentacion del modulo math (alias m)
help(m)

# %%
# Calculemos la tangente de 45°
# SIEMPRE leer la documentacion de la funciones que vamos a utilizar
m.tan(45 * m.pi /180)
# Out:
# 0.9999999999999999

# %%
# La funcion dir
dir(m)

# %%
# Documentacion de la funcion radians
help(m.radians)

# %%
# Calculo de la tangente de 45°
m.tan(m.radians(45))
# Out:
# 0.9999999999999999

# %%
# Accedamos a la documentacion de la funcion gcd
help(m.gcd)

# %%
m.gcd(13,25)
# Out:
# 1

# %% [markdown]
# **Tareita1**
#
# Aprender a utilizar a todos los elementos de interes del modulo math (alias m)
#
#
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp'

# %% [markdown]
# ## El modulo random

# %%
# Importamos el modulo
import random as rnd

# %%
# Leer la documentacion del modulo random (alias rnd)
help(rnd)

# %%
# Recordemos que la funcion dir provee toda la funcionalidad de un modulo
dir(rnd)

# %%
# Documentacion de la funcion gauss que pertenece al modulo random (alias rnd)
help(rnd.gauss)

# %%
# # Libro de referencia para teoria de la probabilidad
# Probability Theory : A Comprehensive Course
# Achim Klenke

# %%
#
r1 = rnd.gauss(-2.3, 0.5)
r1

# -2.455143116792401
# -1.6565467350313394
# -2.176915597299135
# -2.4683289847164125
# Out:
# -2.4683289847164125

# %% [markdown]
# **Tareita2**
#
# Aprender a utilizar todos los componentes del modulo random
#
#
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate'

# %% [markdown]
# # Variables de tipo Cadena de Caracter (str)

# %%
# Definicion
s1 = "PIT705 Python Basico"
s2 = 'Segunda Sesion (06/08/2026)'
s3 = """ Este es el peor curso de mi vida !!!"""

# %%
# Funcion type
type(s1)
# Out:
# str

# %%
# Funcion type
type(s2)
# Out:
# str

# %%
# Funcion type
type(s3)
# Out:
# str

# %% [markdown]
# ## Operaciones con variables de tipo str

# %%
# Concatenacion : +
s4 = s1 + " " + s2
s4

# %%
# typo de dato
type(s4)
# Out:
# str

# %%
# Repeticion : *
s5 = 20 * s1
s6 = s2 * 26

# %%
# tipo de dato
type(s5)
# Out:
# str

# %%
# tipo de dato
type(s6)
# Out:
# str

# %%
s5

# %% [markdown]
# # Definicion y operaciones con variables de naturaleza numerica

# %%
# El nombre de una variable debe ser coherente con su uso
peso = 116      # kilo
estatura = 1.75 # metro

# %%
# type() nos dice el tipo de dato de una variable
type(peso), type(estatura)

# %%
# Python es de tipado dinamico: una variable puede cambiar de tipo
edad = 44
print(type(edad))
edad = "cuarenta y cuatro"
print(type(edad))

# %% [markdown]
# ## Operaciones con variables de naturaleza numerica
#
# - `+` suma  `-` resta  `*` multiplicacion  `/` division  `**` potenciacion
# - `//` cociente entero  `%` residuo
#
# Algoritmo de Euclides: `D = d * q + r`  (q = D // d, r = D % d)

# %%
# Ejemplo: cuadrado de lado 8.5cm, comparado con un area de 60cm2
lado = 8.5
area = lado ** 2
area, area - 60

# %% [markdown]
# ## El modulo math

# %%
import math as m

# Tangente de 45°, de dos formas equivalentes
m.tan(45 * m.pi / 180), m.tan(m.radians(45))

# %%
# Maximo comun divisor
m.gcd(13, 25)

# %% [markdown]
# **Tareita1**: explorar el resto de funciones de `math` (usa `dir(m)` y `help(m.funcion)`).

# %% [markdown]
# ## El modulo random

# %%
import random as rnd

# Numero aleatorio con distribucion normal (media, desviacion estandar)
rnd.gauss(-2.3, 0.5)

# %% [markdown]
# **Tareita2**: explorar el resto de funciones de `random` (usa `dir(rnd)` y `help(rnd.funcion)`).

# %% [markdown]
# # Variables de tipo Cadena de Caracter (str)

# %%
s1 = "PIT705 Python Basico"
s2 = 'Segunda Sesion (06/08/2026)'
s3 = """Este es el peor curso de mi vida !!!"""
type(s1), type(s2), type(s3)

# %% [markdown]
# ## Operaciones con variables de tipo str

# %%
# Concatenacion (+) y repeticion (*)
s4 = s1 + " " + s2
s5 = 20 * s1
s6 = s2 * 26
type(s4), type(s5), type(s6)

# %%
# Combinando concatenacion y repeticion
s7 = 19 * s6 + s5 * 82
type(s7), len(s7)

# %%
# Indexado: primera, segunda, ultima, penultima, antepenultima componente
s1[0], s1[1], s1[-1], s1[-2], s1[-3]

# %%
# Slicing: primeras 5 y ultimas 6 componentes
s3[:5], s3[-6:]

# %%
# len() devuelve el numero de caracteres
len(s1)

# %%
# Acceder fuera de rango produce IndexError
s1[29]

# %%
s6

# %%
# Combinemos estas dos operaciones (Concatenacion y Repeticion)
s7 = 19 * s6 + s5*82

# %%
# tipo de dato
type(s7)
# Out:
# str

# %%
# str es una cadena de caracteres

# %%
# Accdeder a la primera componente de una str
s1[0]
# Out:
# 'P'

# %%
# Segunda componente
s1[1]
# Out:
# 'I'

# %%
# tercera componente
s1[2]
# Out:
# 'T'

# %%
# Ultima componente
s1[-1]
# Out:
# 'o'

# %%
# penultima componente
s1[-2]
# Out:
# 'c'

# %%
# antepenultima componente
s1[-3]
# Out:
# 'i'

# %%
# Accedamos a las primera 5 componentes
s3[:5]
# Out:
# ' Este'

# %%
# Accedamos a las ultimas 6 componentes
s3[-6:]
# Out:
# 'da !!!'

# %%
# Funcion len : Devuelve el numero de elementos (caracteres) de una variables str
len(s7)
# Out:
# 46138

# %%
# NUmero de caracteres de s1
len(s1)
# Out:
# 20

# %%
# Accedamos a la 30ava componente de s1
s1[29]
# Out:
# ---------------------------------------------------------------------------
#
# IndexError                                Traceback (most recent call last)
#
# /tmp/ipykernel_428/1842881778.py in <cell line: 0>()
#
#       1 # Accedamos a la 30ava componente de s1
#
# ----> 2 s1[29]
#
#
#
# IndexError: string index out of range
