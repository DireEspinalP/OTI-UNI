# %% [markdown]
# # Una introduccion al lenguaje de programacion python
#
# - Paradigmas de programacion
#     * Programacion orientada a Objetos
#     * Programacion imperativa y estructurada
#     * Programacion Funcional
#     * Programacion Generica
#
# - Sistemas de Tipos
#     * Tipado dinamico
#     * Tipado Fuerte
#     * Type Hints (A partir de la version 3.5 de python : PEP484)
#
# - Estructuras de datos
#
# - Estructuras de control
#
# **Obs :** Python utiliza la indentacion (espacios en blanco) para delimitar bloques de codigo

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
# Primer Paso : Creacion de variables
x1 = 2026
x2 = 0.02
x3 = "La peor clase de toda mi existencia !!!"
x4 = True
x5 = False
x6 = 666 + 999j

# %%
# Realicemos algunas operaciones triviales usando las variables de naturaleza
# x1 y x2

( x1 + 2.3 * x2 ) / (x2*0.01*x1)
# Out:
# 5000.113524185587

# %%
# Podemos almacenar el resultado de esa operacion en una variable
y1 = ( x1 + 2.3 * x2 ) / (x2*0.01*x1)
y1
# Out:
# 5000.113524185587

# %%
# A partir de crear la variable y1 usando operaciones con las variables ya creadas (x1 y x2)
# puedo realizar operaciones con y1
y2 = (y1 * (x2 + 666))/ (0.0005)
y2
# Out:
# 6660351218.756169

# %%
y3 = (y2*y1)*(x6 + 3.14)
y3
# Out:
# (2.2284043016672148e+16+3.326920969252395e+16j)

# %%
#  la parte real de la variable y3 es : 2.2284043016672148e+16
# Notacion cientifica : 2.2284043016672148 * 10^(16)

# %%
# OBs : Notemos que la letra i NO ES LA UNIDAD IMAGINARIA
12 + 23i
# Out:
#   File "/tmp/ipykernel_2288/3560485395.py", line 1
#
#     12 + 23i
#
#           ^
#
# SyntaxError: invalid decimal literal

# %%
# Pidamos a python que nos comunique el espacio en memoria que ocupan las variables
import sys
sys.getsizeof(x1)
# Out:
# 28

# %%
x1

# Podemos observar que el valor o numero entero 2026 almacenado en la
# variable x1 ocupa 28 B
# Out:
# 2026

# %%
sys.getsizeof(10**10)
# Este numero 10**10 ocupa 32B
# Out:
# 32

# %%
sys.getsizeof(10**100)
# El numero 10**100 ocupa 72B
# Out:
# 72

# %%
sys.getsizeof(10**(-1*x1))
# Este numero mas pequeño que x1 ocupa 24B
# Out:
# 24

# %%
# El interprete que ejecuta nuestro codigo python es IPython
# !ipython --version
# Out:
# 7.34.0

# %%
# Espacio que ocupa en memoria la variable x3
sys.getsizeof(x3)
# Out:
# 80

# %%
x3
# Out:
# 'La peor clase de toda mi existencia !!!'

# %%
txt = "Docente en la Oficina de tecnologías de la información de la Universidad Nacional de Ingeniería - OTI UNI. Egresado de la carrera de Matemática de la Universidad Nacional de Ingeniería con experiencia en la construcción de sistemas de procesamiento distribuido, despliegue de soluciones informáticas en entornos Linux y desarrollo de software usando técnicas de machine learning y deep learning para entornos comerciales y de investigación."
txt
# Out:
# 'Docente en la Oficina de tecnologías de la información de la Universidad Nacional de Ingeniería - OTI UNI. Egresado de la carrera de Matemática de la Universidad Nacional de Ingeniería con experiencia en la construcción de sistemas de procesamiento distribuido, despliegue de soluciones informáticas en entornos Linux y desarrollo de software usando técnicas de machine learning y deep learning para entornos comerciales y de investigación.'

# %%
sys.getsizeof(txt)
# Out:
# 497

# %%
# Espacio de memoria que ocupa una variable logica
sys.getsizeof(x4)
# Out:
# 28

# %%
# Espacio en memoria que ocupa la variable x5
sys.getsizeof(x5)
# Out:
# 28

# %%
# LIbro de referencia
# https://link.springer.com/book/10.1007/978-3-030-16877-3
# Programming for Computations - Python
# A Gentle Introduction to Numerical Simulations with Python 3.6
